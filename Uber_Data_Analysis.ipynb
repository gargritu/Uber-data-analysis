# %% [markdown]
# # What is Exploratory Data Analysis?
# The process of cleaning, transforming, manipulating data into useful information is called Data analysis. We can make future decisions using data analysis.

# %% [markdown]
# # Why Data Analysis?
# Companies have lots of data. To grow business , sometimes data analysis required. By analyzing data we get important topics on which we have to work on to make our business grow by taking necessary decision.

# %% [markdown]
# # Project Goals
# - How long do people travel in Uber?
# - What Hour Do most of the people take uber?
# - What is the purpose of the trip?
# - Which day has the highest number of trips?
# - What are the number of trips each day?

# %% [markdown]
# ## Download the dataset

# %%
#  Shift + Enter
# !wget https://www.dropbox.com/s/i85qjzm0cjh3p4z/UberData.csv
# Out:
# --2024-03-17 07:40:43--  https://www.dropbox.com/s/i85qjzm0cjh3p4z/UberData.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/i85qjzm0cjh3p4z/UberData.csv [following]
# --2024-03-17 07:40:44--  https://www.dropbox.com/s/raw/i85qjzm0cjh3p4z/UberData.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc23f26ae79d38629902c82c686a.dl.dropboxusercontent.com/cd/0/inline/CPOWRM4Cu1Q3L3Z3rvJGwPpbGA0r5HjUzzEM14GCGyuCcByR2jLOGqgQOYlJG1xxZlt9DYd6d-Pi9yTzdKXhhf8hz-DsyYByR-Y7dSyigso-OJ9t6K887XM6fr_2D2OIAk0hm1YLsXNaPBVVsx9u5DHm/file# [following]
# --2024-03-17 07:40:45--  https://uc23f26ae79d38629902c82c686a.dl.dropboxusercontent.com/cd/0/inline/CPOWRM4Cu1Q3L3Z3rvJGwPpbGA0r5HjUzzEM14GCGyuCcByR2jLOGqgQOYlJG1xxZlt9DYd6d-Pi9yTzdKXhhf8hz-DsyYByR-Y7dSyigso-OJ9t6K887XM6fr_2D2OIAk0hm1YLsXNaPBVVsx9u5DHm/file
# Resolving uc23f26ae79d38629902c82c686a.dl.dropboxusercontent.com (uc23f26ae79d38629902c82c686a.dl.dropboxusercontent.com)... 162.125.2.15, 2620:100:6017:15::a27d:20f
# Connecting to uc23f26ae79d38629902c82c686a.dl.dropboxusercontent.com (uc23f26ae79d38629902c82c686a.dl.dropboxusercontent.com)|162.125.2.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86369 (84K) [text/plain]
# Saving to: ‘UberData.csv’
#
# UberData.csv        100%[===================>]  84.34K  --.-KB/s    in 0.01s
#
# 2024-03-17 07:40:45 (5.63 MB/s) - ‘UberData.csv’ saved [86369/86369]

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
# pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.
import numpy as np
# NumPy can be used to perform a wide variety of mathematical operations on arrays.

import matplotlib.pyplot as plt
import seaborn as sns

import warnings         # they are ignoring warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('UberData.csv')

# %%
type(data)   # Dataframe is a combination of rows and columns.
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape        # 1156 -> Rows & 7 -> columns
# Out:
# (1156, 7)

# %%
data.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
data.head(5)
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
# renaming the columns - removing the *
columns = ['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES','PURPOSE']

# %%
# updating the dataframe columns with the new columns.
data.columns = columns

# %%
data.head(n=5)
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data.tail(n=5)
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES         PURPOSE
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
# removing the last unnecassiry row
data = data.drop(index = 1155)

# %%
data.shape
# Out:
# (1155, 7)

# %%
data.tail()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES         PURPOSE
# 1150           Kar?chi    0.7         Meeting
# 1151  Unknown Location    3.9  Temporary Site
# 1152  Unknown Location   16.2         Meeting
# 1153           Gampaha    6.4  Temporary Site
# 1154         Ilukwatta   48.2  Temporary Site

# %%
data['PURPOSE']
# Out:
# 0        Meal/Entertain
# 1                   NaN
# 2       Errand/Supplies
# 3               Meeting
# 4        Customer Visit
#              ...
# 1150            Meeting
# 1151     Temporary Site
# 1152            Meeting
# 1153     Temporary Site
# 1154     Temporary Site
# Name: PURPOSE, Length: 1155, dtype: object

# %%
data['PURPOSE'].unique()
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', 'Meeting',
#        'Customer Visit', 'Temporary Site', 'Between Offices',
#        'Charity ($)', 'Commute', 'Moving', 'Airport/Travel'], dtype=object)

# %%
data['PURPOSE'].nunique()
# Out:
# 10

# %%
data['PURPOSE'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE, dtype: int64

# %%
data.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data.loc[1]              # FOR ACCESS THE ROW
# Out:
# START_DATE    1/2/2016 1:25
# END_DATE      1/2/2016 1:37
# CATEGORY           Business
# START           Fort Pierce
# STOP            Fort Pierce
# MILES                   5.0
# PURPOSE                 NaN
# Name: 1, dtype: object

# %%
data.loc[1].values
# Out:
# array(['1/2/2016 1:25', '1/2/2016 1:37', 'Business', 'Fort Pierce',
#        'Fort Pierce', 5.0, nan], dtype=object)

# %% [markdown]
# # Missing Values

# %%
data.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        0
# CATEGORY        0
# START           0
# STOP            0
# MILES           0
# PURPOSE       502
# dtype: int64

# %% [markdown]
# **Handling missing**
#
# - Dropping rows
# - Drop column
# - Estimate (Approximate) -> Fill

# %%
# data.dropna()

# %%
data = data.fillna(value='Other')

# %%
data.isnull().sum()
# Out:
# START_DATE    0
# END_DATE      0
# CATEGORY      0
# START         0
# STOP          0
# MILES         0
# PURPOSE       0
# dtype: int64

# %%
data.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0            Other
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %% [markdown]
# # Data Types

# %%
data.dtypes
# Out:
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# MILES         float64
# PURPOSE        object
# dtype: object

# %%
# converting string into datetime object.
# changing the datatype
data['START_DATE'] = pd.to_datetime(data['START_DATE'])
data['END_DATE'] = pd.to_datetime(data['END_DATE'])

# %%
data.dtypes
# Out:
# START_DATE    datetime64[ns]
# END_DATE      datetime64[ns]
# CATEGORY              object
# START                 object
# STOP                  object
# MILES                float64
# PURPOSE               object
# dtype: object

# %%
#data['MILES'].astype('str')

# %%
#data.dtypes

# %% [markdown]
# # Feature Engineering

# %%
ts = data['START_DATE'][0]
ts
# Out:
# Timestamp('2016-01-01 21:11:00')

# %%
ts.dayofweek
# Out:
# 4

# %%
ts.day_name()
# Out:
# 'Friday'

# %%
ts.month
# Out:
# 1

# %%
ts.month_name()
# Out:
# 'January'

# %%
ts.day
# Out:
# 1

# %%
ts.year
# Out:
# 2016

# %%
# dt is the way to show year is related to datetime.
data['START_DATE'].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1150    2016
# 1151    2016
# 1152    2016
# 1153    2016
# 1154    2016
# Name: START_DATE, Length: 1155, dtype: int64

# %%
# from above we came to know that it is dataset of 2016

# %%
# Creating New features/Columns

data['HOUR'] = data['START_DATE'].dt.hour
data['DAY'] = data['START_DATE'].dt.day
data['MONTH'] = data['START_DATE'].dt.month
data['DAYOFWEEK'] = data['START_DATE'].dt.dayofweek
data['DAYNAME'] = data['START_DATE'].dt.day_name()

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME
# 0     Friday
# 1   Saturday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday

# %%
data.shape
# Out:
# (1155, 12)

# %% [markdown]
# # Exploratory Data Analysis

# %%
data['CATEGORY'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY, dtype: int64

# %%
sns.countplot(x = data['CATEGORY'])
# Out:
# <Axes: xlabel='CATEGORY', ylabel='count'>

# %% [markdown]
# ### How long (miles) do people travel in Uber?

# %%
data['MILES']
# Out:
# 0        5.1
# 1        5.0
# 2        4.8
# 3        4.7
# 4       63.7
#         ...
# 1150     0.7
# 1151     3.9
# 1152    16.2
# 1153     6.4
# 1154    48.2
# Name: MILES, Length: 1155, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.hist(data['MILES'], bins=100)     #bins = number of boxes
plt.xlabel("Distance (in miles)")
plt.ylabel("Frequency of passanger")
plt.show()

# %% [markdown]
# **Observation:**
# 1. People often use Uber for short rides.

# %% [markdown]
# ## What hour do most people take uber?

# %%
data['HOUR']
# Out:
# 0       21
# 1        1
# 2       20
# 3       17
# 4       14
#         ..
# 1150     1
# 1151    13
# 1152    15
# 1153    21
# 1154    22
# Name: HOUR, Length: 1155, dtype: int64

# %%
data['HOUR'].value_counts()
# Out:
# 15    98
# 17    95
# 13    94
# 18    94
# 14    89
# 16    88
# 12    77
# 11    72
# 20    71
# 19    68
# 10    65
# 9     51
# 21    51
# 8     35
# 22    31
# 23    26
# 0     19
# 7     13
# 1      5
# 5      4
# 6      4
# 3      3
# 2      2
# Name: HOUR, dtype: int64

# %%
sns.countplot(x = data['HOUR'])
# Out:
# <Axes: xlabel='HOUR', ylabel='count'>

# %%
sns.countplot(x = data['HOUR'] , color = 'blue')
# Out:
# <Axes: xlabel='HOUR', ylabel='count'>

# %% [markdown]
# ### Purpose of the Trip

# %%
data['PURPOSE'].value_counts()
# Out:
# Other              502
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE, dtype: int64

# %%
plt.figure(figsize=(15,10))
# data['PURPOSE'].value_counts().plot(kind='bar')
sns.countplot(x = data['PURPOSE'])
# Out:
# <Axes: xlabel='PURPOSE', ylabel='count'>

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME
# 0     Friday
# 1   Saturday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday

# %%
plt.figure(figsize=(10,6))

data['DAY'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### MONTH

# %%
plt.figure(figsize=(10,6))

# data['MONTH'].value_counts().plot(kind='bar')
sns.countplot(x = data['MONTH'])
# Out:
# <Axes: xlabel='MONTH', ylabel='count'>

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME
# 0     Friday
# 1   Saturday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday

# %%
def convertMinutes(time):
  return time.seconds/60

# %%
(data['END_DATE'] - data['START_DATE'])
# Out:
# 0      0 days 00:06:00
# 1      0 days 00:12:00
# 2      0 days 00:13:00
# 3      0 days 00:14:00
# 4      0 days 01:07:00
#              ...
# 1150   0 days 00:07:00
# 1151   0 days 00:18:00
# 1152   0 days 00:35:00
# 1153   0 days 00:18:00
# 1154   0 days 01:43:00
# Length: 1155, dtype: timedelta64[ns]

# %%
(data['END_DATE'] - data['START_DATE']).apply(convertMinutes)
# Out:
# 0         6.0
# 1        12.0
# 2        13.0
# 3        14.0
# 4        67.0
#         ...
# 1150      7.0
# 1151     18.0
# 1152     35.0
# 1153     18.0
# 1154    103.0
# Length: 1155, dtype: float64

# %%
data['DURATION_MIN'] = (data['END_DATE'] - data['START_DATE']).apply(convertMinutes)

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME  DURATION_MIN
# 0     Friday           6.0
# 1   Saturday          12.0
# 2   Saturday          13.0
# 3    Tuesday          14.0
# 4  Wednesday          67.0

# %%
data['DURATION_MIN'].value_counts()
# Out:
# 6.0      51
# 15.0     50
# 10.0     50
# 11.0     48
# 7.0      46
#          ..
# 206.0     1
# 71.0      1
# 72.0      1
# 143.0     1
# 70.0      1
# Name: DURATION_MIN, Length: 99, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['DURATION_MIN'], bins=150)
# Out:
# <Axes: xlabel='DURATION_MIN', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['DURATION_MIN'], bins=150)
# Out:
# <Axes: xlabel='DURATION_MIN', ylabel='Density'>

# %% [markdown]
# # SPEED

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME  DURATION_MIN
# 0     Friday           6.0
# 1   Saturday          12.0
# 2   Saturday          13.0
# 3    Tuesday          14.0
# 4  Wednesday          67.0

# %%
data['SPEED_KMPH'] = (data['MILES']*1.609) / (data['DURATION_MIN']/60)

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME  DURATION_MIN  SPEED_KMPH
# 0     Friday           6.0   82.059000
# 1   Saturday          12.0   40.225000
# 2   Saturday          13.0   35.645538
# 3    Tuesday          14.0   32.409857
# 4  Wednesday          67.0   91.785045

# %%
data['SPEED_KMPH']
# Out:
# 0       82.059000
# 1       40.225000
# 2       35.645538
# 3       32.409857
# 4       91.785045
#           ...
# 1150     9.654000
# 1151    20.917000
# 1152    44.684229
# 1153    34.325333
# 1154    45.176971
# Name: SPEED_KMPH, Length: 1155, dtype: float64

# %%
data['SPEED_KMPH'].mean()
# Out:
# inf

# %%
data[ data['SPEED_KMPH']>10000 ]
# Out:
#              START_DATE            END_DATE  CATEGORY             START  \
# 751 2016-09-06 17:49:00 2016-09-06 17:49:00  Business  Unknown Location
# 761 2016-09-16 07:08:00 2016-09-16 07:08:00  Business  Unknown Location
# 798 2016-10-08 15:03:00 2016-10-08 15:03:00  Business           Karachi
# 807 2016-10-13 13:02:00 2016-10-13 13:02:00  Business         Islamabad
#
#                  STOP  MILES PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK   DAYNAME  \
# 751  Unknown Location   69.1   Other    17    6      9          1   Tuesday
# 761  Unknown Location    1.6   Other     7   16      9          4    Friday
# 798           Karachi    3.6   Other    15    8     10          5  Saturday
# 807         Islamabad    0.7   Other    13   13     10          3  Thursday
#
#      DURATION_MIN  SPEED_KMPH
# 751           0.0         inf
# 761           0.0         inf
# 798           0.0         inf
# 807           0.0         inf

# %%
data[ data['SPEED_KMPH']<10000 ]['SPEED_KMPH'].mean()
# Out:
# 43.13358639335718

# %%
plt.figure(figsize=(10,6))
sns.histplot(data['SPEED_KMPH'])
# Out:
# <Axes: xlabel='SPEED_KMPH', ylabel='Count'>

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  HOUR  DAY  MONTH  DAYOFWEEK  \
# 0      Fort Pierce    5.1   Meal/Entertain    21    1      1          4
# 1      Fort Pierce    5.0            Other     1    2      1          5
# 2      Fort Pierce    4.8  Errand/Supplies    20    2      1          5
# 3      Fort Pierce    4.7          Meeting    17    5      1          1
# 4  West Palm Beach   63.7   Customer Visit    14    6      1          2
#
#      DAYNAME  DURATION_MIN  SPEED_KMPH
# 0     Friday           6.0   82.059000
# 1   Saturday          12.0   40.225000
# 2   Saturday          13.0   35.645538
# 3    Tuesday          14.0   32.409857
# 4  Wednesday          67.0   91.785045

# %%
data.to_csv('cleaned_data.csv', index=False)
